# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Height_Weight_Dataset.csv')
df.head()
# Out:
#    Age  Height
# 0   10     138
# 1   11     138
# 2   12     138
# 3   13     139
# 4   14     139

# %%
x=df.iloc[:,0:1].values
y=df.iloc[:,1].values

# %%
from sklearn.model_selection import train_test_split

# %%
train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
from sklearn.linear_model import LinearRegression

# %%
linreg=LinearRegression()
linreg.fit(train_x,train_y)
# Out:
# LinearRegression()

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
polynom=PolynomialFeatures(degree=60)
x_polynom=polynom.fit_transform(train_x)
x_polynom
# Out:
# array([[1.00000000e+000, 1.20000000e+001, 1.44000000e+002, ...,
#         3.91302183e+062, 4.69562620e+063, 5.63475144e+064],
#        [1.00000000e+000, 5.00000000e+001, 2.50000000e+003, ...,
#         3.46944695e+098, 1.73472348e+100, 8.67361738e+101],
#        [1.00000000e+000, 2.10000000e+001, 4.41000000e+002, ...,
#         4.88336397e+076, 1.02550643e+078, 2.15356351e+079],
#        ...,
#        [1.00000000e+000, 7.40000000e+001, 5.47600000e+003, ...,
#         2.60279369e+108, 1.92606733e+110, 1.42528982e+112],
#        [1.00000000e+000, 5.70000000e+001, 3.24900000e+003, ...,
#         6.93013395e+101, 3.95017635e+103, 2.25160052e+105],
#        [1.00000000e+000, 5.40000000e+001, 2.91600000e+003, ...,
#         3.01188281e+100, 1.62641672e+102, 8.78265027e+103]],
#       shape=(49, 61))

# %%
poly_reg=LinearRegression()
poly_reg.fit(x_polynom,train_y)
# Out:
# LinearRegression()

# %%
plt.scatter(train_x,train_y,color='red')
plt.plot(train_x,poly_reg.predict(polynom.fit_transform(train_x)),color='blue')
plt.title('polynom regration')
plt.xlabel('Age')
plt.ylabel('Height')
plt.show()

# %%
print(type(linreg))
# Out:
# <class 'sklearn.linear_model._base.LinearRegression'>

# %%
from sklearn.linear_model import LinearRegression
linreg = LinearRegression()
linreg.fit(train_x, train_y)
# Out:
# LinearRegression()

# %%
y_predict_slr=linreg.predict(test_x)
from sklearn import metrics
r_squre=metrics.r2_score(test_y,y_predict_slr)
print('r squre error assoocted simple linner regration',r_squre)
# Out:
# r squre error assoocted simple linner regration 0.8727873738671587

# %%
y_predict_pr=poly_reg.predict(polynom.fit_transform(test_x))
from sklearn import metrics
r_squre=metrics.r2_score(test_y,y_predict_pr)
print('r squre error assoocted simple linner regration',r_squre)
# Out:
# r squre error assoocted simple linner regration 0.9936103884812809

# %%
linreg.predict([[53]])
# Out:
# array([168.52966207])

# %%
poly_reg.predict(polynom.fit_transform([[53]]))
# Out:
# array([161.64166822])
