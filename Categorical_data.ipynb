# %% [markdown]
# # how to handle catagorical data

# %%
import pandas as pd
import numpy as np # import libary numpy and pandas

# %%
df = pd.DataFrame([['green','L',10,'class1'],
                   ['red','M',20,'class2']
                   ,['pink','XL',30,'class3'],
                   ['Blue','XXL',50,'class4']]
                 )
df
# Out:
#        0    1   2       3
# 0  green    L  10  class1
# 1    red    M  20  class2
# 2   pink   XL  30  class3
# 3   Blue  XXL  50  class4

# %%
df.columns=['colur','Size','Price','Target']
df
# Out:
#    colur Size  Price  Target
# 0  green    L     10  class1
# 1    red    M     20  class2
# 2   pink   XL     30  class3
# 3   Blue  XXL     50  class4

# %%
size_mapping = {'L': 1, 'M': 2, 'XL': 3, 'XXL': 4}

# %%
df['Size'] = df['Size'].map(size_mapping)

# %%
df
# Out:
#    colur  Size  Price  Target
# 0  green     1     10  class1
# 1    red     2     20  class2
# 2   pink     3     30  class3
# 3   Blue     4     50  class4

# %%
# create dummy varibles

# %%
# Select all columns except 'Target'
df_features = df[df.columns[:-1]]
# Apply get_dummies only on categorical columns
df2 = pd.get_dummies(df_features)
print(df2)
# Out:
#    Size  Price  colur_Blue  colur_green  colur_pink  colur_red
# 0     1     10       False         True       False      False
# 1     2     20       False        False       False       True
# 2     3     30       False        False        True      False
# 3     4     50        True        False       False      False

# %%
df['Target']=df.Target.map({'class1':0,'class2':1,'class3':2,'class4':3})

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %%
label=[]
encoder=LabelEncoder()
encoder.fit_transform(label)
# Out:
# array([], dtype=int64)

# %%
x=df.iloc[:,:-1] #input
y=df.iloc[:,-1] #output

# %%
from sklearn.impute import  SimpleImputer

# %%
imputer=SimpleImputer(missing_values=np.nan,strategy='mean')
imputer
# Out:
# SimpleImputer()

# %%
x.iloc[:,1:3]=imputer.fit_transform(x.iloc[:,1:3
